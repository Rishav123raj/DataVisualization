# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
auto = pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.distplot(auto['normalized_losses'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11732\1371470564.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(auto['normalized_losses'])

# %%
sns.distplot(auto['normalized_losses'], kde=False, rug=True)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8788\1661077597.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(auto['normalized_losses'], kde=False, rug=True)

# %%
sns.jointplot(data=auto, x='engine_size', y='horsepower', kind='kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.jointplot(data=auto, x='engine_size', y='horsepower', kind='kde')
#       2 plt.show()
#
# NameError: name 'auto' is not defined

# %%
sns.pairplot(auto[['normalized_losses','engine_size','wheel_base']])

# %%
sns.swarmplot(data=auto, x='fuel_type', y='horsepower')
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(data=auto, x='number_of_doors', y='horsepower', hue=auto['fuel_type'])
# Out:
# <Axes: xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.countplot(data=auto, x='body_style')
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.pointplot(data=auto, x='fuel_system', y='horsepower')
# Out:
# <Axes: xlabel='fuel_system', ylabel='horsepower'>

# %%
sns.lmplot(data=auto, y='peak_rpm', x='horsepower', hue='fuel_type')
